# %% [markdown]
# # Data visualization

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df=pd.read_csv(r"C:\Users\durge\OneDrive\Desktop\python\Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# # Let's try to generate a histogram of some data using the Artist Layer

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(10000)
plt.hist(x,100)
plt.title(r'C:\Users\durge\OneDrive\Desktop\python\Iris.csv')
plt.savefig('matplotlib_histogram.png')
plt.show()

# %% [markdown]
# # Matplotlib - Plot Function

# %%
plt.plot(5,5,'o')
plt.show()

# %% [markdown]
# # Matplotlib Backends - Inline

# %%
plt.plot(5,5,'o')

plt.ylabel("Y")
plt.xlabel("x")
plt.title("plotting Figure")
plt.show()

# %% [markdown]
# # Dataset on immigration to Iris

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # area plot

# %%
import matplotlib as mlp
import matplotlib.pyplot as plt

# %%
df.plot(kind='area')

plt.title('trend the iris dataset')
plt.ylabel('PetalLengthCm')
plt.xlabel('PetalWidthCm')

plt.show()

# %%
df.plot(kind='area')

plt.title('trend the iris dataset')
plt.ylabel('id')
plt.xlabel('SepalWidthCm')

plt.show()

# %% [markdown]
# # creating Line plots

# %%
Iris=list(map(str,range(1,150)))

df.plot(kind = 'line')
plt.title('iris dataset')
plt.ylabel('number of SepalLengthCm')
plt.xlabel('SepalWidthCm')

plt.show()

# %% [markdown]
# # Create Histogram

# %%
df.plot(kind='hist')

plt.title('trend the iris dataset')
plt.ylabel(' SepalLengthCm')
plt.xlabel('SepalWidthCm')

plt.show()

# %%
df.plot(kind='hist')

plt.title('trend the iris dataset')
plt.ylabel(' PetalLengthCm')
plt.xlabel('PetalWidthCm')

plt.show()

# %%
df.plot(kind='hist')

plt.title('trend the iris dataset')
plt.ylabel(' SepalLengthCm ')
plt.xlabel('Id')

plt.show()

# %%
df.plot(kind='hist')

plt.title('trend the iris dataset')
plt.ylabel('Species')
plt.xlabel('Id')

plt.show()

# %% [markdown]
# # Bar chart

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df.plot(kind='bar', figsize=(15, 10))

plt.xlabel('SepalLengthCm') # add to x-label to the plot
plt.ylabel('SepalWidthCm') # add y-label to the plot
plt.title('Iris dataset') # add title to the plot

plt.show()
