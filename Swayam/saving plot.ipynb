# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # let's plot sin wave from -3*pi to 3pi

# %%
np.linspace(-3*np.pi,3*np.pi)
# Out:
# array([-9.42477796, -9.04009315, -8.65540833, -8.27072352, -7.8860387 ,
#        -7.50135389, -7.11666907, -6.73198426, -6.34729944, -5.96261463,
#        -5.57792981, -5.193245  , -4.80856018, -4.42387537, -4.03919055,
#        -3.65450574, -3.26982093, -2.88513611, -2.5004513 , -2.11576648,
#        -1.73108167, -1.34639685, -0.96171204, -0.57702722, -0.19234241,
#         0.19234241,  0.57702722,  0.96171204,  1.34639685,  1.73108167,
#         2.11576648,  2.5004513 ,  2.88513611,  3.26982093,  3.65450574,
#         4.03919055,  4.42387537,  4.80856018,  5.193245  ,  5.57792981,
#         5.96261463,  6.34729944,  6.73198426,  7.11666907,  7.50135389,
#         7.8860387 ,  8.27072352,  8.65540833,  9.04009315,  9.42477796])

# %%
x=np.linspace(-3*np.pi,3*np.pi)

# %%
print(x)
# Out:
# [-9.42477796 -9.04009315 -8.65540833 -8.27072352 -7.8860387  -7.50135389
#  -7.11666907 -6.73198426 -6.34729944 -5.96261463 -5.57792981 -5.193245
#  -4.80856018 -4.42387537 -4.03919055 -3.65450574 -3.26982093 -2.88513611
#  -2.5004513  -2.11576648 -1.73108167 -1.34639685 -0.96171204 -0.57702722
#  -0.19234241  0.19234241  0.57702722  0.96171204  1.34639685  1.73108167
#   2.11576648  2.5004513   2.88513611  3.26982093  3.65450574  4.03919055
#   4.42387537  4.80856018  5.193245    5.57792981  5.96261463  6.34729944
#   6.73198426  7.11666907  7.50135389  7.8860387   8.27072352  8.65540833
#   9.04009315  9.42477796]

# %%
len(x)
# Out:
# 50

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x))
plt.savefig("sin.png")
plt.show()

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x),'r')
plt.savefig("sin.pdf")
plt.show()

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x),'b')
plt.savefig("sin.jpg")
plt.show()

# %%
pwd
# Out:
# 'C:\\Users\\durge\\OneDrive\\Desktop\\practice_python\\Swayam'

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x),'g')
plt.savefig('sin.ps')
plt.show()

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x),'m')
plt.savefig('sin.eps')
plt.show()

# %%
np.linspace(-3*np.pi,3*np.pi)
plt.plot(x,np.sin(x),'g')
plt.savefig('sin.svg')
plt.show()
